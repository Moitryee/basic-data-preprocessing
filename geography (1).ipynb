# %%
import pandas as pd 
import numpy as np
df=pd.read_csv("landslide.csv")

# %%
df.head(4)
# Out:
#   source_name                                        source_link  event_id  \
# 0         AGU  https://blogs.agu.org/landslideblog/2008/10/14...       684
# 1   Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...       956
# 2    CBS News  https://www.cbsnews.com/news/dozens-missing-af...       973
# 3     Reuters  https://in.reuters.com/article/idINIndia-41450...      1067
#
#                event_date  event_time  \
# 0  08/01/2008 12:00:00 AM         NaN
# 1  01/02/2009 02:00:00 AM         NaN
# 2  01/19/2007 12:00:00 AM         NaN
# 3  07/31/2009 12:00:00 AM         NaN
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# ...

# %%
df.shape
#there are 11033 rows in this data
# Out:
# (11033, 31)

# %%
df.columns
# Out:
# Index(['source_name', 'source_link', 'event_id', 'event_date', 'event_time',
#        'event_title', 'event_description', 'location_description',
#        'location_accuracy', 'landslide_category', 'landslide_trigger',
#        'landslide_size', 'landslide_setting', 'fatality_count', 'injury_count',
#        'storm_name', 'photo_link', 'notes', 'event_import_source',
#        'event_import_id', 'country_name', 'country_code',
#        'admin_division_name', 'admin_division_population',
#        'gazeteer_closest_point', 'gazeteer_distance', 'submitted_date',
#        'created_date', 'last_edited_date', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# # this data is all about landslide in different countries.
# ##  the goal of identifying rainfall-triggered landslide events around the world, regardless of size, impacts or location
# ### column discription
# ** there are many columns around 31 columns in the data**
# 1. source_name : here it shows the name of the news channel where the news has been premier
# 2. source_link: here it is the website link of the landslide news.
# 3. event id : the id of the given event
# 4. event_date: the event date with time.
# 5. event_time: time of the event.
# 6. event_title: head line of the news
# 7. event_discrip: discription of the event
# 8. location_discription: the landslide location discription
# 9. location_accuracy: how close your location estimate is to the actual location of the landslide.
# 10. landslide_category: catagory of the location
# 11. landslide_trigger: refers to an external stimulus, such as rainfall, downpour etc.
# 12. landslide_size: catagory of the landslide size.
# 13. landslide_setting: what is the type of region the landslide happen
# 14. fatality_count: number of death
# 15. injury count: Number of injured persons
# 16. storm_name: name of the storme
# 17. photo_link: link of the photo
# 18. notes: note thing of the landslide
# 19. event_import_source: from where news has been taken
# 20. event_import_id : id of the import source
# 21. country_name: name of the it effected
# 22. country_code: code of the country
# 23. admin_division_name : name of the area it is effected
# 24. admin_division_population : the population of the area
# 25. gazeteer_closest_point : location of the landslide
# 26. gazeteer_distance: distance in gazeteer
# 27. submitted_date: date it is submitted
# 28. created_date : date it is created
# 29. last_edited_date
# 30. logitude : logitutude of the location
# 31. latitude: latitude of the location

# %%
## data assessing and cleaning
## as the number of columns are large in numbers so deleting the columns that are reduntended
df.drop("source_link", inplace= True, axis= 1)
df.drop("event_import_source", inplace= True, axis= 1)
df.drop("event_import_id", inplace= True, axis= 1)
df.drop("photo_link", inplace= True, axis= 1)
df.drop("notes", inplace= True, axis= 1)
df.drop("submitted_date", inplace= True, axis=1)
df.drop("created_date", inplace= True, axis=1)
df.drop("last_edited_date", inplace= True, axis= 1)

# %%
df.drop("country_code", axis=1 , inplace = True)

# %%
df.drop("landslide_setting", axis=1, inplace= True)

# %%
df.columns
# Out:
# Index(['source_name', 'event_id', 'event_date', 'event_time', 'event_title',
#        'event_description', 'location_description', 'location_accuracy',
#        'landslide_category', 'landslide_trigger', 'landslide_size',
#        'fatality_count', 'injury_count', 'storm_name', 'country_name',
#        'admin_division_name', 'admin_division_population',
#        'gazeteer_closest_point', 'gazeteer_distance', 'longitude', 'latitude'],
#       dtype='object')

# %%
## to see big view of the data in excel
#df.to_csv("new_landslide.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11033 entries, 0 to 11032
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   source_name                11033 non-null  object
#  1   event_id                   11033 non-null  int64
#  2   event_date                 11033 non-null  object
#  3   event_time                 0 non-null      float64
#  4   event_title                11033 non-null  object
#  5   event_description          10171 non-null  object
#  6   location_description       10931 non-null  object
#  7   location_accuracy          11031 non-null  object
#  8   landslide_category         11032 non-null  object
#  9   landslide_trigger          11010 non-null  object
#  10  landslide_size             11024 non-null  object
#  11  fatality_count             9648 non-null   float64
#  12  injury_count               5359 non-null   float64
# ...

# %% [markdown]
# # data assessing
# ** Dirty data **
# 1. there are missing values in many columns.
# 2. many rows are null in injury replace with "not injured".
# 3. landslide setting are missing so deleting the column.
# 4. there are country name and country code which is repetted so removing country code column.
#
# ** messy data **
# 1. event date contains date with time so separatly we havr to write date and time.
# 2. submitted date and created date are not required in our analysis only the event date is required to be there.
# 3. in location accuracy column we have to keep only numbers not "km" and change location_accuracy(km)

# %%
df.head(4)
# Out:
#   source_name  event_id              event_date  event_time  \
# 0         AGU       684  08/01/2008 12:00:00 AM         NaN
# 1   Oregonian       956  01/02/2009 02:00:00 AM         NaN
# 2    CBS News       973  01/19/2007 12:00:00 AM         NaN
# 3     Reuters      1067  07/31/2009 12:00:00 AM         NaN
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description location_accuracy  \
# ...

# %%
## there are 5674 null values in injury_count column 
## so filling the column with not injured where null vlaues are there.
#code 
df["injury_count"]=df["injury_count"].fillna(0.0)

# %%
#testing
df["injury_count"].sample(4)
# Out:
# 6958    0.0
# 7251    0.0
# 5254    0.0
# 6774    0.0
# Name: injury_count, dtype: float64

# %%
#df['landslide_setting'].isnull().sum()
## 50% of the data are unknown so deleting the column
#df["landslide_setting"].value_counts()

# %%
df.head(4)
# Out:
#   source_name  event_id              event_date  event_time  \
# 0         AGU       684  08/01/2008 12:00:00 AM         NaN
# 1   Oregonian       956  01/02/2009 02:00:00 AM         NaN
# 2    CBS News       973  01/19/2007 12:00:00 AM         NaN
# 3     Reuters      1067  07/31/2009 12:00:00 AM         NaN
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description location_accuracy  \
# ...

# %%
df.columns
# Out:
# Index(['source_name', 'event_id', 'event_date', 'event_time', 'event_title',
#        'event_description', 'location_description', 'location_accuracy',
#        'landslide_category', 'landslide_trigger', 'landslide_size',
#        'fatality_count', 'injury_count', 'storm_name', 'country_name',
#        'admin_division_name', 'admin_division_population',
#        'gazeteer_closest_point', 'gazeteer_distance', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.sample(3)
# Out:
#              source_name  event_id              event_date  event_time  \
# 9841  blogs.seattletimes      4653  12/04/2012 12:00:00 AM         NaN
# 8260          Oregon DOT      8168  08/16/2015 08:16:00 AM         NaN
# 2104         bclocalnews      2812  12/12/2010 08:00:00 AM         NaN
#
#                                             event_title  \
# 9841                  Train service, Mukiteo to Everett
# 8260                                 OR 37, milepost 15
# 2104  Isabella Point rd, Salt Spring(Saltspring) Isl...
#
#                                       event_description  \
# 9841  A Tuesday morning mudslide has shut down Sound...
# 8260                                                NaN
# 2104  December 15, 2010 10:00 AM  The heavy rain tha...
#
#                                    location_description location_accuracy  \
# 9841                  Train service, Mukiteo to Everett               5km
# ...

# %%
## as both time and date are given in the event time column so puting time in the event time column and only date in the date column
#code
df["event_time"]=df["event_date"].str.split(" ").str.get(1)

# %%
#testing
df.sample(3)
# Out:
#                   source_name  event_id              event_date event_time  \
# 8706          maps.google.com      1701  04/06/2010 12:00:00 AM   12:00:00
# 4985  timesofindia.indiatimes      2380  09/03/2010 12:00:00 AM   12:00:00
# 8062      The Weather Channel      8861  10/11/2015 12:00:00 AM   12:00:00
#
#                            event_title  \
# 8706                            Sumare
# 4985  Bhatwari, Rishikesh-Gangotri hwy
# 8062                      Mount Steele
#
#                                       event_description  \
# 8706  slip below the towers of residential location ...
# 4985  Sep 5, 2010, 05.13am IST  DEHRADUN: Over 8,000...
# 8062  On Oct. 11, massive amounts of ice and rock ca...
#
#                   location_description location_accuracy landslide_category  \
# 8706                            Sumare               1km          landslide
# 4985  Bhatwari, Rishikesh-Gangotri hwy               5km          landslide
# ...

# %%
#code
df["event_date"]=df["event_date"].str.split(" ").str.get(0)

# %%
#testing
df.sample(4)
# Out:
#              source_name  event_id  event_date event_time  \
# 9384             ptinews      1987  06/15/2010   12:00:00
# 7730   newsinfo.inquirer      3542  05/27/2011   12:00:00
# 10906      The Chronicle     10554  04/30/2017   01:22:00
# 3445     thenational.com       327  10/26/2007   12:00:00
#
#                                          event_title  \
# 9384   rails between Mahur and Wadringdisa(?), Assam
# 7730         Halsema Highway, Mountain Province, CAR
# 10906                   Landslide on Salmon Creek Rd
# 3445                      Alotau, Milne Bay province
#
#                                        event_description  \
# 9384   Train services in central Assam's North Cachar...
# 7730   A section of Halsema Highway in Mountain Provi...
# 10906  Landslide closes Salmon Creek road for entire ...
# 3445                                  4 injured in house
#
#                                     location_description location_accuracy  \
# ...

# %%
## checking the null values 
df.isnull().sum()
## as some columns are having null values they are event_disription, location discription etc
# Out:
# source_name                      0
# event_id                         0
# event_date                       0
# event_time                       0
# event_title                      0
# event_description              862
# location_description           102
# location_accuracy                2
# landslide_category               1
# landslide_trigger               23
# landslide_size                   9
# fatality_count                1385
# injury_count                     0
# storm_name                   10456
# country_name                  1562
# admin_division_name           1637
# admin_division_population     1562
# gazeteer_closest_point        1563
# gazeteer_distance             1562
# longitude                        0
# latitude                         0
# dtype: int64

# %%
df['fatality_count'].fillna(df['fatality_count'].median,inplace= True)
# Out:
# C:\Users\MOITRYEE\AppData\Local\Temp\ipykernel_4656\4094812175.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<bound method Series.median of 0        11.0
# 1         0.0
# 2        10.0
# 3         1.0
# 4         0.0
#          ...
# 11028    27.0
# 11029     2.0
# 11030     1.0
# 11031    24.0
# 11032     2.0
# Name: fatality_count, Length: 11033, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['fatality_count'].fillna(df['fatality_count'].median,inplace= True)

# %%
#as 90% of the storm_name column values are not there so deleting the column
df.drop('storm_name', axis=1,inplace= True)

# %%
#df.drop('last_edited_date', axis=1, inplace = True)

# %%
df['admin_division_population'].fillna(df['admin_division_population'].median, inplace= True)
# Out:
# C:\Users\MOITRYEE\AppData\Local\Temp\ipykernel_4656\1120405746.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<bound method Series.median of 0             0.0
# 1         36619.0
# 2         14708.0
# 3         20908.0
# 4        798634.0
#            ...
# 11028         NaN
# 11029         NaN
# 11030         NaN
# 11031         NaN
# 11032         NaN
# Name: admin_division_population, Length: 11033, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['admin_division_population'].fillna(df['admin_division_population'].median, inplace= True)

# %%
df['gazeteer_closest_point'].value_counts()
# Out:
# gazeteer_closest_point
# Niterói           48
# Waldport          47
# Rio de Janeiro    45
# Kohima            44
# Florence          39
#                   ..
# Sandwick           1
# Jefferson          1
# Mamuju             1
# Looe               1
# Archis             1
# Name: count, Length: 4389, dtype: int64

# %%
# as highest frequency of the gazeteer_closest_point column is Niteroi so replacing missing values with them
df['gazeteer_closest_point'].fillna(df["gazeteer_closest_point"].mode, inplace= True)

# %%
df['gazeteer_distance'].fillna(df['gazeteer_distance'].mean, inplace= True)
# Out:
# C:\Users\MOITRYEE\AppData\Local\Temp\ipykernel_4656\3207691079.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<bound method Series.mean of 0        41.02145
# 1         0.60342
# 2         0.85548
# 3         0.75395
# 4         2.02204
#            ...
# 11028         NaN
# 11029         NaN
# 11030         NaN
# 11031         NaN
# 11032         NaN
# Name: gazeteer_distance, Length: 11033, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['gazeteer_distance'].fillna(df['gazeteer_distance'].mean, inplace= True)

# %%
df['country_name'].fillna(df['country_name'].mode, inplace= True)

# %%
df['admin_division_name'].fillna(df['admin_division_name'].mode, inplace= True)

# %%
df['landslide_trigger'].fillna(df['landslide_trigger'].mode, inplace= True)

# %%
df.isnull().sum()
# Out:
# source_name                    0
# event_id                       0
# event_date                     0
# event_time                     0
# event_title                    0
# event_description            862
# location_description         102
# location_accuracy              2
# landslide_category             1
# landslide_trigger              0
# landslide_size                 9
# fatality_count                 0
# injury_count                   0
# country_name                   0
# admin_division_name            0
# admin_division_population      0
# gazeteer_closest_point         0
# gazeteer_distance              0
# longitude                      0
# latitude                       0
# dtype: int64

# %%
df.head(4)
# Out:
#   source_name  event_id  event_date event_time  \
# 0         AGU       684  08/01/2008   12:00:00
# 1   Oregonian       956  01/02/2009   02:00:00
# 2    CBS News       973  01/19/2007   12:00:00
# 3     Reuters      1067  07/31/2009   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description location_accuracy  \
# 0      Sigou Village, Loufan County, Shanxi Province           unknown
# ...

# %%
df['location_accuracy'].value_counts()
# Out:
# location_accuracy
# 5km        3178
# 1km        2185
# 25km       1470
# 10km       1435
# exact      1386
# 50km        794
# unknown     542
# 100km        25
# 250km        16
# Name: count, dtype: int64

# %%
#replaceing the unknown value to 5 km 
df['location_accuracy'].replace({'unknown':'5'}, inplace= True)
df['location_accuracy'].replace({'exact':'5'}, inplace= True)

# %%
## lets check the datatypes of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11033 entries, 0 to 11032
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   source_name                11033 non-null  object
#  1   event_id                   11033 non-null  int64
#  2   event_date                 11033 non-null  object
#  3   event_time                 11033 non-null  object
#  4   event_title                11033 non-null  object
#  5   event_description          10171 non-null  object
#  6   location_description       10931 non-null  object
#  7   location_accuracy          11031 non-null  object
#  8   landslide_category         11032 non-null  object
#  9   landslide_trigger          11033 non-null  object
#  10  landslide_size             11024 non-null  object
#  11  fatality_count             11033 non-null  object
#  12  injury_count               11033 non-null  float64
# ...

# %% [markdown]
# ### as we can see that column which shows the numerical values are also object type which should be integer type
# ### the column with date and time are also object time which should be changed

# %%
df['event_date']= pd.to_datetime(df['event_date'])

# %%
#df['event_time']= pd.to_datetime(df['event_time'])

# %%
df.head(4)
# Out:
#   source_name  event_id event_date event_time  \
# 0         AGU       684 2008-08-01   12:00:00
# 1   Oregonian       956 2009-01-02   02:00:00
# 2    CBS News       973 2007-01-19   12:00:00
# 3     Reuters      1067 2009-07-31   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description location_accuracy  \
# 0      Sigou Village, Loufan County, Shanxi Province                 5
# ...

# %%
df["location_accuracy"]=df["location_accuracy"].str.split("k").str.get(0)

# %%
df["location_accuracy"].fillna(df["location_accuracy"].mode, inplace= True)

# %%
df["location_accuracy"].isnull().sum()
# Out:
# 0

# %%
## changing location accuracy object datatype to numeric datatype
df["location_accuracy"]=pd.to_numeric(df["location_accuracy"], errors= "coerce")

# %%
df.rename(columns={"location_accuracy" : "location_accuracy(km)"}, inplace = True)

# %%
## testing the code
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11033 entries, 0 to 11032
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   source_name                11033 non-null  object
#  1   event_id                   11033 non-null  int64
#  2   event_date                 11033 non-null  datetime64[ns]
#  3   event_time                 11033 non-null  object
#  4   event_title                11033 non-null  object
#  5   event_description          10171 non-null  object
#  6   location_description       10931 non-null  object
#  7   location_accuracy(km)      11031 non-null  float64
#  8   landslide_category         11032 non-null  object
#  9   landslide_trigger          11033 non-null  object
#  10  landslide_size             11024 non-null  object
#  11  fatality_count             11033 non-null  object
#  12  injury_count               11033 non-null  float64
# ...

# %%
df.head(4)
# Out:
#   source_name  event_id event_date event_time  \
# 0         AGU       684 2008-08-01   12:00:00
# 1   Oregonian       956 2009-01-02   02:00:00
# 2    CBS News       973 2007-01-19   12:00:00
# 3     Reuters      1067 2009-07-31   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description  location_accuracy(km)  \
# 0      Sigou Village, Loufan County, Shanxi Province                    5.0
# ...

# %%
#changing the object data type to numeric datatype
df["admin_division_population"]=pd.to_numeric(df["admin_division_population"], errors= "coerce")
df["fatality_count"]=pd.to_numeric(df["fatality_count"], errors= "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11033 entries, 0 to 11032
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   source_name                11033 non-null  object
#  1   event_id                   11033 non-null  int64
#  2   event_date                 11033 non-null  datetime64[ns]
#  3   event_time                 11033 non-null  object
#  4   event_title                11033 non-null  object
#  5   event_description          10171 non-null  object
#  6   location_description       10931 non-null  object
#  7   location_accuracy(km)      11031 non-null  float64
#  8   landslide_category         11032 non-null  object
#  9   landslide_trigger          11033 non-null  object
#  10  landslide_size             11024 non-null  object
#  11  fatality_count             9648 non-null   float64
#  12  injury_count               11033 non-null  float64
# ...

# %%
df.head(3)
# Out:
#   source_name  event_id event_date event_time  \
# 0         AGU       684 2008-08-01   12:00:00
# 1   Oregonian       956 2009-01-02   02:00:00
# 2    CBS News       973 2007-01-19   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
#
#                                 location_description  location_accuracy(km)  \
# 0      Sigou Village, Loufan County, Shanxi Province                    5.0
# 1                                Lake Oswego, Oregon                    5.0
# 2  San Ramon district, 195 miles northeast of the...                   10.0
#
# ...

# %%
## importing all the neccasary libraries for data analysis
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Exploratory data analysis

# %%
## univariate data analysis
## there are various column lets analysis one by one
## column source name is a catagorical variable.
top_5_source_name=df["source_name"].value_counts().head(5)
top_5_source_name.plot(kind="bar", color="red")
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.title("Top 5 Categories by Frequency")
# Out:
# Text(0.5, 1.0, 'Top 5 Categories by Frequency')

# %% [markdown]
# ## The Oregon DOT channel shows the news highest number of times compared to others.

# %%
## lets analyse the numerical column 
df.describe()
# Out:
#            event_id                     event_date  location_accuracy(km)  \
# count  11033.000000                          11033           11031.000000
# mean    5598.953141  2013-03-11 22:21:27.555515136              11.333061
# min        1.000000            1988-11-07 00:00:00               1.000000
# 25%     2785.000000            2010-11-09 00:00:00               5.000000
# 50%     5563.000000            2013-07-12 00:00:00               5.000000
# 75%     8435.000000            2015-10-19 00:00:00              10.000000
# max    11221.000000            2017-09-28 00:00:00             250.000000
# std     3249.228647                            NaN              16.520221
#
#        fatality_count  injury_count  admin_division_population     longitude  \
# count     9648.000000  11033.000000               9.471000e+03  11033.000000
# mean         3.219424      0.365177               1.577600e+05      2.520441
# ...

# %%
## if we consider the location_accuracy column then 75% and max values are showing highly differ this column can be outlier
sns.boxplot(data=df, x="location_accuracy(km)")
## as we can see there are outliers
# Out:
# <Axes: xlabel='location_accuracy(km)'>

# %%
# fatality_count,admin_division_population,longitude, latitude these columns need normalization for futher analysis
## the numbers in this column are vary so much so taking all the column into (-1,1) range is important.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df["fatality_count"]=scaler.fit_transform(df["fatality_count"].values.reshape(-1, 1))

# %%
df["admin_division_population"]=scaler.fit_transform(df["admin_division_population"].values.reshape(-1, 1))
df["longitude"]=scaler.fit_transform(df["longitude"].values.reshape(-1, 1))
df["latitude"]=scaler.fit_transform(df["latitude"].values.reshape(-1, 1))

# %%
df.describe()
# Out:
#            event_id                     event_date  location_accuracy(km)  \
# count  11033.000000                          11033           11031.000000
# mean    5598.953141  2013-03-11 22:21:27.555515136              11.333061
# min        1.000000            1988-11-07 00:00:00               1.000000
# 25%     2785.000000            2010-11-09 00:00:00               5.000000
# 50%     5563.000000            2013-07-12 00:00:00               5.000000
# 75%     8435.000000            2015-10-19 00:00:00              10.000000
# max    11221.000000            2017-09-28 00:00:00             250.000000
# std     3249.228647                            NaN              16.520221
#
#        fatality_count  injury_count  admin_division_population     longitude  \
# count    9.648000e+03  11033.000000               9.471000e+03  1.103300e+04
# mean     2.945865e-18      0.365177              -1.350414e-17  4.636914e-17
# ...

# %%
df.head(5)
# Out:
#    source_name  event_id event_date event_time  \
# 0          AGU       684 2008-08-01   12:00:00
# 1    Oregonian       956 2009-01-02   02:00:00
# 2     CBS News       973 2007-01-19   12:00:00
# 3      Reuters      1067 2009-07-31   12:00:00
# 4  The Freeman      2603 2010-10-16   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
# 4                    sitio Bakilid in barangay Lahug
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
# 4  Another landslide in sitio Bakilid in barangay...
#
# ...

# %%
df["injury_count"].isnull().sum()
# Out:
# 0

# %%
df["injury_count"].sample(4)
# Out:
# 8632    0.0
# 1733    1.0
# 8987    0.0
# 3276    0.0
# Name: injury_count, dtype: float64

# %%
df.head(5)
# Out:
#    source_name  event_id event_date event_time  \
# 0          AGU       684 2008-08-01   12:00:00
# 1    Oregonian       956 2009-01-02   02:00:00
# 2     CBS News       973 2007-01-19   12:00:00
# 3      Reuters      1067 2009-07-31   12:00:00
# 4  The Freeman      2603 2010-10-16   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
# 4                    sitio Bakilid in barangay Lahug
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
# 4  Another landslide in sitio Bakilid in barangay...
#
# ...

# %%
## catagorical variable 
df["landslide_category"].unique()
# Out:
# array(['landslide', 'mudslide', 'complex', 'rock_fall', 'debris_flow',
#        'riverbank_collapse', 'other', 'unknown', 'lahar',
#        'snow_avalanche', 'creep', 'earth_flow', 'translational_slide',
#        nan, 'topple'], dtype=object)

# %%
top_5_landslide_category=df["landslide_category"].value_counts().head(7)
top_5_landslide_category.plot(kind="bar", color="red")
plt.xlabel("Category")
plt.ylabel("Frequency")
plt.title("Top 7 Categories by Frequency")
# Out:
# Text(0.5, 1.0, 'Top 7 Categories by Frequency')

# %% [markdown]
# ** Majority of the times landslide occurs in the world **

# %%
df['landslide_trigger'].replace({'unknown':'downpour'}, inplace = True)

# %%
top_landslide_trigger=df["landslide_trigger"].value_counts().head(7)
top_landslide_trigger.plot(kind="bar", color="green")
plt.xlabel("landslide cause")
plt.ylabel("Frequency")
plt.title("Top 7 Categories by Frequency")
# Out:
# Text(0.5, 1.0, 'Top 7 Categories by Frequency')

# %% [markdown]
# ## downpour is the major cause of landslide

# %%
df["landslide_size"].value_counts()
# Out:
# landslide_size
# medium          6551
# small           2767
# unknown          851
# large            750
# very_large       102
# catastrophic       3
# Name: count, dtype: int64

# %%
df['landslide_size'].replace({'unknown':'medium'}, inplace = True)

# %%
sns.histplot(data=df, x="landslide_size")
# Out:
# C:\Users\MOITRYEE\AppData\Local\anaconda3\python\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='landslide_size', ylabel='Count'>

# %% [markdown]
# ** medium landslide size is the major size of landslide around the world **

# %%
df.head(4)
# Out:
#   source_name  event_id event_date event_time  \
# 0         AGU       684 2008-08-01   12:00:00
# 1   Oregonian       956 2009-01-02   02:00:00
# 2    CBS News       973 2007-01-19   12:00:00
# 3     Reuters      1067 2009-07-31   12:00:00
#
#                                          event_title  \
# 0      Sigou Village, Loufan County, Shanxi Province
# 1                                Lake Oswego, Oregon
# 2  San Ramon district, 195 miles northeast of the...
# 3                                   Dailekh district
#
#                                    event_description  \
# 0  occurred early in morning, 11 villagers buried...
# 1  Hours of heavy rain are to blame for an overni...
# 2  (CBS/AP) At least 10 people died and as many a...
# 3  One person was killed in Dailekh district, pol...
#
#                                 location_description  location_accuracy(km)  \
# 0      Sigou Village, Loufan County, Shanxi Province                    5.0
# ...

# %%
df.columns
# Out:
# Index(['source_name', 'event_id', 'event_date', 'event_time', 'event_title',
#        'event_description', 'location_description', 'location_accuracy(km)',
#        'landslide_category', 'landslide_trigger', 'landslide_size',
#        'fatality_count', 'injury_count', 'country_name', 'admin_division_name',
#        'admin_division_population', 'gazeteer_closest_point',
#        'gazeteer_distance', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11033 entries, 0 to 11032
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   source_name                11033 non-null  object
#  1   event_id                   11033 non-null  int64
#  2   event_date                 11033 non-null  datetime64[ns]
#  3   event_time                 11033 non-null  object
#  4   event_title                11033 non-null  object
#  5   event_description          10171 non-null  object
#  6   location_description       10931 non-null  object
#  7   location_accuracy(km)      11031 non-null  float64
#  8   landslide_category         11032 non-null  object
#  9   landslide_trigger          11033 non-null  object
#  10  landslide_size             11024 non-null  object
#  11  fatality_count             9648 non-null   float64
#  12  injury_count               11033 non-null  float64
# ...
